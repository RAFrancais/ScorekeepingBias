# %% [markdown]
# # Detecting Bias in NBA Scorekeeping

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
mpgdf = pd.read_excel('Mean Point guard.xlsx')

# %%
mpgdf.head(5)
# Out:
#          NBA Team  Usage Rate  Points  Rebounds  Assists  Minutes Played  \
# 0          Boston        34.7    29.8       2.7      5.6            33.8
# 1     Boston Away        33.8    28.0       2.4      6.2            33.8
# 2       Cleveland        29.2    24.4       3.3      6.6            34.4
# 3  Cleveland Away        32.5    26.1       3.0      5.0            35.7
# 4         Toronto        23.9    21.8       4.6      7.0            37.5
#
#     TeamFG%  TeamFG  TeamFGA  Team PPG
# 0  0.445961    39.2     87.9     105.4
# 1  0.430108    36.0     83.7     105.3
# 2  0.445067    39.7     89.2     104.6
# 3  0.470056    41.6     88.5     109.8
# 4  0.446281    37.8     84.7     103.2

# %% [markdown]
# ## Summary Statistics

# %%
mpgdf.describe()
# Out:
#        Usage Rate     Points   Rebounds    Assists  Minutes Played    TeamFG%  \
# count   62.000000  62.000000  62.000000  62.000000       62.000000  62.000000
# mean    26.028333  18.308333   4.248333   6.415000       31.620000   0.457114
# std      5.643723   6.509632   1.886678   1.984324        3.707986   0.014395
# min     14.400000   6.200000   1.500000   3.000000       24.300000   0.430108
# 25%     22.250000  13.350000   3.225000   5.000000       29.100000   0.448420
# 50%     26.350000  18.050000   3.950000   6.138333       32.500000   0.456287
# 75%     29.000000  23.000000   4.675000   7.150000       34.325000   0.467137
# max     42.900000  32.100000  10.700000  11.400000       37.500000   0.486452
#
#           TeamFG    TeamFGA    Team PPG
# count  62.000000  62.000000   62.000000
# mean   39.025000  85.370877  105.595000
# std     1.823215   2.916143    4.430649
# min    33.900000  77.500000   94.800000
# 25%    37.875000  83.550000  102.975000
# 50%    39.100000  85.555000  105.700000
# 75%    40.075000  87.475000  109.075000
# max    42.500000  90.900000  115.100000

# %% [markdown]
# ## Importing Logistic Regression Dataset from Stata

# %%
nbadta = pd.read_stata('biasinNBAscorekeepingFINAL.dta')

# %%
nbadta.head(5)
# Out:
#      G       Date   Tm  Away  Opp        F   GS                  MP    FG  \
# 0  1.0 2016-10-26  OKC   1.0  PHI   W (+6)  1.0 1900-01-01 12:23:00  11.0
# 1  2.0 2016-10-28  OKC   0.0  PHO   W (+3)  1.0 1900-01-01 21:19:00  17.0
# 2  3.0 2016-10-30  OKC   0.0  LAL  W (+17)  1.0 1900-01-01 09:39:00  11.0
# 3  4.0 2016-11-02  OKC   1.0  LAC   W (+2)  1.0 1900-01-01 08:39:00  14.0
# 4  5.0 2016-11-03  OKC   1.0  GSW  L (-26)  1.0 1900-01-01 04:52:00   4.0
#
#     FGA  ...   PTS  GmSc    AB   USG    AD  TeamPPG  TeamFG  TripleDouble  \
# 0  21.0  ...  32.0  28.4  10.0  31.8  48.5    103.0   0.415             0
# 1  44.0  ...  51.0  32.9   7.0  50.2  58.1    113.0   0.417             1
# 2  21.0  ...  33.0  32.3   9.0  36.0  77.9    113.0   0.474             1
# 3  30.0  ...  35.0  15.9  12.0  56.8  54.8     85.0   0.405             0
# 4  15.0  ...  20.0  13.9  -9.0  39.2  58.7     96.0   0.402             0
#
#    TeamPPGPTS     lnPTS
# 0        71.0  3.465736
# 1        62.0  3.931826
# 2        80.0  3.496508
# 3        50.0  3.555348
# 4        76.0  2.995732
#
# [5 rows x 35 columns]

# %% [markdown]
# ### Renaming Column

# %%
nbadta.rename(columns = {'TeamPPGPTS': 'tPPG'}, inplace = True)

# %% [markdown]
# ### Removing an extraneous row

# %%
nbadta[0:82]
# Out:
#        G       Date   Tm  Away  Opp        F   GS                      MP  \
# 0    1.0 2016-10-26  OKC   1.0  PHI   W (+6)  1.0 1900-01-01 12:23:00.000
# 1    2.0 2016-10-28  OKC   0.0  PHO   W (+3)  1.0 1900-01-01 21:19:00.000
# 2    3.0 2016-10-30  OKC   0.0  LAL  W (+17)  1.0 1900-01-01 09:39:00.000
# 3    4.0 2016-11-02  OKC   1.0  LAC   W (+2)  1.0 1900-01-01 08:39:00.000
# 4    5.0 2016-11-03  OKC   1.0  GSW  L (-26)  1.0 1900-01-01 04:52:00.000
# ..   ...        ...  ...   ...  ...      ...  ...                     ...
# 77  78.0 2017-04-05  OKC   1.0  MEM   W (+3)  1.0 1900-01-01 13:32:00.000
# 78  79.0 2017-04-07  OKC   1.0  PHO  L (-21)  1.0 1900-01-01 12:24:00.000
# 79  80.0 2017-04-09  OKC   1.0  DEN   W (+1)  1.0 1900-01-01 12:57:00.001
# 80  81.0 2017-04-12  OKC   0.0  DEN   L (-6)  1.0 1899-12-31 18:19:00.000
# 81   NaN        NaT        NaN                NaN                     NaT
#
#       FG   FGA  ...   PTS  GmSc    AB   USG    AD  TeamPPG  TeamFG  \
# 0   11.0  21.0  ...  32.0  28.4  10.0  31.8  48.5    103.0   0.415
# 1   17.0  44.0  ...  51.0  32.9   7.0  50.2  58.1    113.0   0.417
# 2   11.0  21.0  ...  33.0  32.3   9.0  36.0  77.9    113.0   0.474
# 3   14.0  30.0  ...  35.0  15.9  12.0  56.8  54.8     85.0   0.405
# 4    4.0  15.0  ...  20.0  13.9  -9.0  39.2  58.7     96.0   0.402
# ..   ...   ...  ...   ...   ...   ...   ...   ...      ...     ...
# 77  14.0  25.0  ...  45.0  37.0   2.0  44.3  67.0    103.0   0.435
# 78   6.0  25.0  ...  23.0  10.2 -15.0  42.2  40.4     99.0   0.370
# 79  17.0  32.0  ...  50.0  45.6  10.0  42.9  72.5    106.0   0.417
# 80   2.0  10.0  ...   5.0   2.8  -5.0  28.3  55.5    105.0   0.426
# 81   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN      NaN     NaN
#
#     TripleDouble   tPPG     lnPTS
# 0              0   71.0  3.465736
# 1              1   62.0  3.931826
# 2              1   80.0  3.496508
# 3              0   50.0  3.555348
# 4              0   76.0  2.995732
# ..           ...    ...       ...
# 77             0   58.0  3.806663
# 78             0   76.0  3.135494
# 79             1   56.0  3.912023
# 80             0  100.0  1.609438
# 81            42    NaN       NaN
#
# [82 rows x 35 columns]

# %%
nbadta = nbadta[0:81]

# %%
nbadta.shape
# Out:
# (81, 35)

# %%
nbadta = nbadta.drop(columns=['MP', 'Tm', 'Opp', 'F'])

# %%
for col in nbadta.columns: 
    print(col)
# Out:
# G
# Date
# Away
# GS
# FG
# FGA
# K
# P
# PA
# N
# FT
# FTA
# Q
# ORB
# DRB
# TRB
# AST
# STL
# BLK
# TOV
# PF
# PTS
# GmSc
# AB
# USG
# AD
# TeamPPG
# TeamFG
# TripleDouble
# tPPG
# lnPTS

# %%
print(len(col))
# Out:
# 5

# %%
nbadta.describe()
# Out:
#                G       Away    GS         FG        FGA          K          P  \
# count  81.000000  81.000000  81.0  81.000000  81.000000  81.000000  81.000000
# mean   41.000000   0.493827   1.0  10.172840  23.962963   0.425136   2.469136
# std    23.526581   0.503077   0.0   3.859372   6.736921   0.119384   1.911063
# min     1.000000   0.000000   1.0   2.000000   6.000000   0.200000   0.000000
# 25%    21.000000   0.000000   1.0   7.000000  20.000000   0.333000   1.000000
# 50%    41.000000   0.000000   1.0  10.000000  23.000000   0.433000   2.000000
# 75%    61.000000   1.000000   1.0  13.000000  28.000000   0.500000   3.000000
# max    81.000000   1.000000   1.0  21.000000  44.000000   1.000000   8.000000
#
#               PA          N         FT  ...        PTS       GmSc         AB  \
# count  81.000000  80.000000  81.000000  ...  81.000000  81.000000  81.000000
# mean    7.197531   0.331625   8.765432  ...  31.580247  24.920988   3.086420
# std     3.396394   0.214090   3.921963  ...  10.490310   9.161901  13.003074
# min     0.000000   0.000000   0.000000  ...   5.000000   2.800000 -36.000000
# 25%     5.000000   0.167000   6.000000  ...  25.000000  20.200000  -6.000000
# 50%     7.000000   0.300000   9.000000  ...  31.000000  25.200000   7.000000
# 75%     9.000000   0.475250  11.000000  ...  38.000000  30.800000  12.000000
# max    16.000000   0.833000  17.000000  ...  58.000000  45.600000  26.000000
#
#              USG          AD     TeamPPG     TeamFG  TripleDouble        tPPG  \
# count  81.000000   81.000000   81.000000  81.000000     81.000000   81.000000
# mean   41.548148   56.488889  106.679012   0.452358      0.518519   75.098765
# std     7.794006   16.732633   10.901637   0.051112      0.502770   12.476583
# min    20.100000    0.000000   80.000000   0.338000      0.000000   50.000000
# 25%    36.200000   46.400000   99.000000   0.419000      0.000000   64.000000
# 50%    40.900000   56.500000  108.000000   0.454000      1.000000   75.000000
# 75%    47.800000   65.700000  114.000000   0.494000      1.000000   83.000000
# max    58.000000  100.000000  132.000000   0.566000      1.000000  104.000000
#
#            lnPTS
# count  81.000000
# mean    3.388211
# std     0.387937
# min     1.609438
# 25%     3.218876
# 50%     3.433987
# 75%     3.637586
# max     4.060443
#
# [8 rows x 30 columns]

# %% [markdown]
# ## Correlation Matrix

# %%
corr = nbadta[['Away', 'USG', 'PTS', 'AST', 'TRB', 'tPPG']].corr()

# %%
corr
# Out:
#           Away       USG       PTS       AST       TRB      tPPG
# Away  1.000000  0.163779  0.046874 -0.220563 -0.017967 -0.272737
# USG   0.163779  1.000000  0.640298 -0.520353 -0.210530 -0.729913
# PTS   0.046874  0.640298  1.000000 -0.162785  0.096503 -0.561058
# AST  -0.220563 -0.520353 -0.162785  1.000000  0.421763  0.559947
# TRB  -0.017967 -0.210530  0.096503  0.421763  1.000000  0.101515
# tPPG -0.272737 -0.729913 -0.561058  0.559947  0.101515  1.000000

# %%
corr.style.background_gradient(cmap = 'coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
# #T_57ab4_row0_col0,#T_57ab4_row1_col1,#T_57ab4_row2_col2,#T_57ab4_row3_col3,#T_57ab4_row4_col4,#T_57ab4_row5_col5{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_57ab4_row0_col1{
#             background-color:  #e1dad6;
#             color:  #000000;
#         }#T_57ab4_row0_col2{
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }#T_57ab4_row0_col3{
#             background-color:  #7a9df8;
#             color:  #000000;
#         }#T_57ab4_row0_col4{
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }#T_57ab4_row0_col5{
#             background-color:  #92b4fe;
#             color:  #000000;
#         }#T_57ab4_row1_col0{
#             background-color:  #adc9fd;
#             color:  #000000;
#         }#T_57ab4_row1_col2{
#             background-color:  #f29072;
#             color:  #000000;
#         }#T_57ab4_row1_col3,#T_57ab4_row1_col4,#T_57ab4_row1_col5,#T_57ab4_row5_col0,#T_57ab4_row5_col1,#T_57ab4_row5_col2{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_57ab4_row2_col0,#T_57ab4_row2_col4{
#             background-color:  #8db0fe;
#             color:  #000000;
#         }#T_57ab4_row2_col1{
#             background-color:  #ef886b;
#             color:  #000000;
#         }#T_57ab4_row2_col3{
#             background-color:  #88abfd;
#             color:  #000000;
#         }#T_57ab4_row2_col5{
#             background-color:  #5875e1;
#             color:  #000000;
#         }#T_57ab4_row3_col0{
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }#T_57ab4_row3_col1{
#             background-color:  #6180e9;
#             color:  #000000;
#         }#T_57ab4_row3_col2,#T_57ab4_row5_col4{
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }#T_57ab4_row3_col4{
#             background-color:  #e2dad5;
#             color:  #000000;
#         }#T_57ab4_row3_col5{
#             background-color:  #f59c7d;
#             color:  #000000;
#         }#T_57ab4_row4_col0{
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }#T_57ab4_row4_col1{
#             background-color:  #9ebeff;
#             color:  #000000;
#         }#T_57ab4_row4_col2{
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }#T_57ab4_row4_col3{
#             background-color:  #f4c6af;
#             color:  #000000;
#         }#T_57ab4_row4_col5{
#             background-color:  #d8dce2;
#             color:  #000000;
#         }#T_57ab4_row5_col3{
#             background-color:  #f7a98b;
#             color:  #000000;
#         }</style><table id="T_57ab4_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Away</th>        <th class="col_heading level0 col1" >USG</th>        <th class="col_heading level0 col2" >PTS</th>        <th class="col_heading level0 col3" >AST</th>        <th class="col_heading level0 col4" >TRB</th>        <th class="col_heading level0 col5" >tPPG</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_57ab4_level0_row0" class="row_heading level0 row0" >Away</th>
#                         <td id="T_57ab4_row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_57ab4_row0_col1" class="data row0 col1" >0.16</td>
#                         <td id="T_57ab4_row0_col2" class="data row0 col2" >0.05</td>
#                         <td id="T_57ab4_row0_col3" class="data row0 col3" >-0.22</td>
#                         <td id="T_57ab4_row0_col4" class="data row0 col4" >-0.02</td>
#                         <td id="T_57ab4_row0_col5" class="data row0 col5" >-0.27</td>
#             </tr>
#             <tr>
#                         <th id="T_57ab4_level0_row1" class="row_heading level0 row1" >USG</th>
#                         <td id="T_57ab4_row1_col0" class="data row1 col0" >0.16</td>
#                         <td id="T_57ab4_row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_57ab4_row1_col2" class="data row1 col2" >0.64</td>
#                         <td id="T_57ab4_row1_col3" class="data row1 col3" >-0.52</td>
#                         <td id="T_57ab4_row1_col4" class="data row1 col4" >-0.21</td>
#                         <td id="T_57ab4_row1_col5" class="data row1 col5" >-0.73</td>
#             </tr>
#             <tr>
#                         <th id="T_57ab4_level0_row2" class="row_heading level0 row2" >PTS</th>
#                         <td id="T_57ab4_row2_col0" class="data row2 col0" >0.05</td>
#                         <td id="T_57ab4_row2_col1" class="data row2 col1" >0.64</td>
#                         <td id="T_57ab4_row2_col2" class="data row2 col2" >1.00</td>
#                         <td id="T_57ab4_row2_col3" class="data row2 col3" >-0.16</td>
#                         <td id="T_57ab4_row2_col4" class="data row2 col4" >0.10</td>
#                         <td id="T_57ab4_row2_col5" class="data row2 col5" >-0.56</td>
#             </tr>
#             <tr>
#                         <th id="T_57ab4_level0_row3" class="row_heading level0 row3" >AST</th>
#                         <td id="T_57ab4_row3_col0" class="data row3 col0" >-0.22</td>
#                         <td id="T_57ab4_row3_col1" class="data row3 col1" >-0.52</td>
#                         <td id="T_57ab4_row3_col2" class="data row3 col2" >-0.16</td>
#                         <td id="T_57ab4_row3_col3" class="data row3 col3" >1.00</td>
#                         <td id="T_57ab4_row3_col4" class="data row3 col4" >0.42</td>
#                         <td id="T_57ab4_row3_col5" class="data row3 col5" >0.56</td>
#             </tr>
#             <tr>
#                         <th id="T_57ab4_level0_row4" class="row_heading level0 row4" >TRB</th>
#                         <td id="T_57ab4_row4_col0" class="data row4 col0" >-0.02</td>
#                         <td id="T_57ab4_row4_col1" class="data row4 col1" >-0.21</td>
#                         <td id="T_57ab4_row4_col2" class="data row4 col2" >0.10</td>
#                         <td id="T_57ab4_row4_col3" class="data row4 col3" >0.42</td>
#                         <td id="T_57ab4_row4_col4" class="data row4 col4" >1.00</td>
#                         <td id="T_57ab4_row4_col5" class="data row4 col5" >0.10</td>
#             </tr>
#             <tr>
#                         <th id="T_57ab4_level0_row5" class="row_heading level0 row5" >tPPG</th>
#                         <td id="T_57ab4_row5_col0" class="data row5 col0" >-0.27</td>
#                         <td id="T_57ab4_row5_col1" class="data row5 col1" >-0.73</td>
#                         <td id="T_57ab4_row5_col2" class="data row5 col2" >-0.56</td>
#                         <td id="T_57ab4_row5_col3" class="data row5 col3" >0.56</td>
#                         <td id="T_57ab4_row5_col4" class="data row5 col4" >0.10</td>
#                         <td id="T_57ab4_row5_col5" class="data row5 col5" >1.00</td>
#             </tr>
#     </tbody></table>

# %%
plt.scatter(nbadta.AST, nbadta.TripleDouble)

# %%
model = LogisticRegression()

# %%
x_cols = nbadta[['Away', 'USG', 'PTS', 'AST', 'TRB', 'tPPG']]
y_cols = nbadta[['TripleDouble']]
X = nbadta[['AST']]

# %%
X_train, X_test y_train, y_test = train_test_split(nbadta[['Away', 'USG', 'PTS', 'AST', 'TRB', 'tPPG']], nbadta.TripleDouble, train_size = 0.9)
# Out:
#   File "<ipython-input-39-2ea920bb5d60>", line 1
#     X_train, X_test y_train, y_test = train_test_split(nbadta[['Away', 'USG', 'PTS', 'AST', 'TRB', 'tPPG']], nbadta.TripleDouble, train_size = 0.9)
#                     ^
# SyntaxError: invalid syntax

# %%
X_train, X_test y_train, y_test = train_test_split(x_cols, y_cols, test_size = 0.1)
# Out:
#   File "<ipython-input-40-0e31550dc1f9>", line 1
#     X_train, X_test y_train, y_test = train_test_split(x_cols, y_cols, test_size = 0.1)
#                     ^
# SyntaxError: invalid syntax

# %%
nbadta.dtypes
# Out:
# G                      float64
# Date            datetime64[ns]
# Away                   float64
# GS                     float64
# FG                     float64
# FGA                    float64
# K                      float64
# P                      float64
# PA                     float64
# N                      float64
# FT                     float64
# FTA                    float64
# Q                      float64
# ORB                    float64
# DRB                    float64
# TRB                    float64
# AST                    float64
# STL                    float64
# BLK                    float64
# TOV                    float64
# PF                     float64
# PTS                    float64
# GmSc                   float64
# AB                     float64
# USG                    float64
# AD                     float64
# TeamPPG                float64
# TeamFG                 float64
# TripleDouble              int8
# tPPG                   float64
# lnPTS                  float32
# dtype: object

# %%
pd.to_numeric(nbadta[['Away', 'USG', 'PTS', 'AST', 'TRB', 'tPPG']])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-5349b2f2afd2> in <module>
# ----> 1 pd.to_numeric(nbadta[['Away', 'USG', 'PTS', 'AST', 'TRB', 'tPPG']])
#
# D:\Anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     139         values = np.array([arg], dtype="O")
#     140     elif getattr(arg, "ndim", 1) > 1:
# --> 141         raise TypeError("arg must be a list, tuple, 1-d array, or Series")
#     142     else:
#     143         values = arg
#
# TypeError: arg must be a list, tuple, 1-d array, or Series

# %%
X_train, X_test, y_train, y_test = train_test_split(nbadta[['Away', 'USG', 'PTS', 'AST', 'TRB', 'tPPG']], nbadta.TripleDouble, test_size = 0.1)

# %%
X_test
# Out:
#     Away   USG   PTS   AST   TRB  tPPG
# 20   0.0  41.0  28.0  12.0  17.0  73.0
# 21   1.0  40.9  32.0  12.0  13.0  70.0
# 27   0.0  52.4  46.0   7.0  11.0  62.0
# 79   1.0  42.9  50.0  10.0  16.0  56.0
# 73   1.0  52.4  57.0  11.0  13.0  57.0
# 17   0.0  34.3  17.0  15.0  13.0  89.0
# 54   0.0  49.3  47.0   8.0  11.0  67.0
# 46   0.0  49.7  45.0   3.0   8.0  64.0
# 10   1.0  42.2  33.0   8.0  15.0  55.0

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([1, 1, 0, 1, 1, 1, 0, 0, 0], dtype=int8)
